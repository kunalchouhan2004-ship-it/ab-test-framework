# %%
import sys
import os
import pandas as pd
import importlib

# --- Path setup ---
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.insert(0, project_root)

# --- Load framework ---
import ab_test_framework
importlib.reload(ab_test_framework)
from ab_test_framework import *

# --- Load cleaned data ---
cleaned_path = os.path.join(project_root, 'data', 'cookie_cats_cleaned.csv')
df = pd.read_csv(cleaned_path)

print("Data shape:", df.shape)
print("Groups:", df['version'].value_counts().to_dict())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       7 project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
#       8 sys.path.insert(0, project_root)
#       9
#      10 # --- Load framework ---
# ---> 11 import ab_test_framework
#      12 importlib.reload(ab_test_framework)
#      13 from ab_test_framework import *
#      14
#
# File ~\AB_Test_FrameWork\ab_test_framework.py:87
#      83     return 'continuous'
#      85 # ── Helper: Normality Check ───────────────────────────────────────
# ---> 87 def check_normality(series, alpha=ALPHA_DEFAULT):
#      88     """
#      89     Tests whether a numeric Series is normally distributed.
#      90
#    (...)    109         - p_value     : float
#     110     """
#     111     n = len(series)
#
# NameError: name 'ALPHA_DEFAULT' is not defined
